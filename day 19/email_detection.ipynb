# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("SMSSpamCollection.unknown", sep='\t', header=None, names=['label','message'])

# %%
df=pd.DataFrame(df)

# %%
x=df['message']
df['label']=df['label'].map({'ham':0,'spam':1})

X_train, X_test, y_train, y_test = train_test_split(df['message'],df['label'],test_size=0.25,random_state=42)

vectorizer=CountVectorizer()
X_train_vec=vectorizer.fit_transform(X_train)
X_test_vec=vectorizer.transform(X_test)

# %%
model=LogisticRegression()
model.fit(X_train_vec,y_train)

y_pred=model.predict(X_test_vec)
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
acc=accuracy_score(y_test,y_pred)
print(f"\nAccuracy: {acc:.2f}")

#Detailed classification report 
print("\nClassification Report: ")
print(classification_report(y_test,y_pred))
# Out:
# Accuracy: 0.98
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1207
#            1       1.00      0.89      0.94       186
#
#     accuracy                           0.98      1393
#    macro avg       0.99      0.94      0.97      1393
# weighted avg       0.99      0.98      0.98      1393

# %%
new_message=["Win a brand new car by entering the contest now!"]
new_message_vec=vectorizer.transform(new_message)
prediction=model.predict(new_message_vec)
print("\nMessage prediction:","Spam"if prediction[0]==1 else"Ham")
# Out:
# Message prediction: Ham

# %%
new_message=input("enter the mail: ")
new_message=list(new_message)
prediction=model.predict(new_message_vec)
print("\nMessage prediction:","ham"if prediction[0]==1 else"Spam")
# Out:
# Message prediction: Spam
