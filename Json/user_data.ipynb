# %%
import json

# %%
my_portfolio = {
    "name": "Satkriti Khadka",
    "email": "satkriti@gmail.com",
    "hobbies": ["traveling", "coding", "dancing"],
    "address": {
        "district": "Kathmandu",
        "zip-code":"07"
    }
}

# %%
my_portfolio_json = json.dumps(my_portfolio)
print(my_portfolio_json)
# Out:
# {"name": "Satkriti Khadka", "email": "satkriti@gmail.com", "hobbies": ["traveling", "coding", "dancing"], "address": {"district": "Kathmandu", "zip-code": "07"}}
