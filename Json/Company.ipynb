# %%
import json

complex_json_string = """
{
  "companyName": "Tech Solutions Inc.",
  "products": [
    {
      "id": "P001",
      "name": "SuperWidget",
      "specs": {
        "storage": "256GB",
        "ram": "8GB"
      }
    },
    {
      "id": "P002",
      "name": "MegaDevice",
      "specs": {
        "storage": "512GB",
        "ram": "16GB"
      }
    }
  ]
}
"""
data = json.loads(complex_json_string)
print(data)

company_name = data['companyName']
print(company_name)

# 2. Get the name of the first product


# 3. Get the RAM of the second product
# Access 'products' list (index 1), then 'specs' object, then 'ram' key
# Out:
# {'companyName': 'Tech Solutions Inc.', 'products': [{'id': 'P001', 'name': 'SuperWidget', 'specs': {'storage': '256GB', 'ram': '8GB'}}, {'id': 'P002', 'name': 'MegaDevice', 'specs': {'storage': '512GB', 'ram': '16GB'}}]}
# Tech Solutions Inc.

# %%
first_product_name = data['products'][0]['name']
print(first_product_name)
# Out:
# SuperWidget

# %%
second_product_ram = data['products'][1]['specs']['ram']
print(second_product_ram)
# Out:
# 16GB
